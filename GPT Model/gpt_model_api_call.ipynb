# %% [markdown]
# #### Define Imports

# %%
#%pip install openai

# %%
import sys
sys.path.insert(0,'../')
from environment import env
from environment import gpt_model_functions

# %% [markdown]
# #### API Call

# %%
query = 'What activities can I do at Bryce Canyon National Park?'
gpt_model_functions.api_call(query)
# Out:
# ['Astronomy',
#  'Biking',
#  'Camping',
#  'Food',
#  'Guided Tours',
#  'Hands-On',
#  'Hiking',
#  'Horse Trekking',
#  'Junior Ranger Program',
#  'Museum Exhibits',
#  'Park Film',
#  'Shopping',
#  'Skiing',
#  'Snowshoeing',
#  'Wildlife Watching']

# %%
query = 'What alerts are there at Bryce Canyon National Park?'
gpt_model_functions.api_call(query)
# Out:
#                                      id  \
# 0  9840308A-02FB-4A2F-90A3-E5597EB3881B
# 1  8833A24A-3F71-4E6E-9254-FF7743304115
#
#                                                  url  \
# 0  https://www.nps.gov/brca/planyourvisit/conditi...
# 1  https://www.nps.gov/brca/planyourvisit/basicin...
#
#                                                title parkCode  \
# 0                                   Main Road Status     brca
# 1  Bryce Canyon is Open - No Reservations Require...     brca
#
#                                          description     category  \
# 0  The main park road is fully open to Rainbow Po...  Information
# 1  No reservations are required to enter Bryce Ca...  Information
#
#   relatedRoadEvents        lastIndexedDate
# 0                []  2024-04-02 13:59:18.0
# 1                []  2024-02-16 15:58:11.0

# %%
query = 'Where is Bryce Canyon National Park located?'
gpt_model_functions.api_call(query)
# Out:
#                      fullName parkCode state  \
# 0  Bryce Canyon National Park     brca    UT
# 1  Bryce Canyon National Park     brca    UT
#
#                                          description postalCode   city  \
# 0  Hoodoos (irregular columns of rock) exist on e...      84764  Bryce
# 1  Hoodoos (irregular columns of rock) exist on e...      84764  Bryce
#
#   stateCode countryCode provinceTerritoryCode           line1      type line3  \
# 0        UT          US                            Highway 63  Physical
# 1        UT          US                        P.O Box 640201   Mailing
#
#                         line2
# 0  Bryce Canyon National Park
# 1

# %%
query = 'How much are the enterance fees for Bryce Canyon National Park?'
gpt_model_functions.api_call(query)
# Out:
#   parkCode  isFeeFreePark  isInteragencyPassAccepted cashless  \
# 0     brca          False                       True      Yes
#
#                                      feesAtWorkUrl  \
# 0  https://www.nps.gov/brca/planyourvisit/fees.htm
#
#                               entranceFeeDescription entrancePassDescription  \
# 0  All park visitors are required to purchase a r...
#
#    isParkingFeePossible parkingDetailsUrl timedEntryHeading  ...  \
# 0                 False                                      ...
#
#   paidParkingHeading  paidParkingDescription customFeeHeading  \
# 0
#
#   customFeeDescription customFeeLinkUrl customFeeLinkText  \
# 0
#
#                                 contentOrderOrdinals relatedMultiSitePasses  \
# 0  {'entranceFee': 1, 'timedEntry': 2, 'paidParki...                     []
#
#                                                 fees  \
# 0  [{'entranceFeeType': 'Entrance - Private Vehic...
#
#                                               passes
# ...

# %%
query = 'What are the amenities at Bryce Canyon National Park?'
gpt_model_functions.api_call(query)
# Out:
#                                       id                            name  \
# 0   A1B0AD01-740C-41E7-8412-FBBEDD5F1443                ATM/Cash Machine
# 1   4E4D076A-6866-46C8-A28B-A129E2B8F3DB                Accessible Rooms
# 2   B509969B-F06A-4DCC-BBB3-134964D896E2                    Amphitheater
# 3   CBD31D2A-DD1A-4C5D-88C1-67B6B7147CE9     Assistive Listening Systems
# 4   7DC6C690-2BC3-4344-9691-EF9FCFB6E506               Audio Description
# ..                                   ...                             ...
# 61  4D4C1C32-793D-4440-8098-DBCA0126EDFD        Trash/Litter Receptacles
# 62  23682251-700A-4DE2-8FD8-BD680F53DF82  Water - Bottle-Filling Station
# 63  9A652919-D548-4850-8053-798CDC2C762B        Water - Drinking/Potable
# 64  EAB59B1F-2FA1-4545-A322-2C19149AF7FC           Wheelchair Accessible
# 65  1CF3D18E-C6A7-4462-9990-86B59383A9C3           Wheelchairs Available
#
#                                categories
# 0   [Convenience, Souvenirs and Supplies]
# ...

# %%
query = 'What events are happening at Bryce Canyon National Park?'
gpt_model_functions.api_call(query)
# Out:
#                                             location updateuser contactname  \
# 0  Main hall in the Bryce Canyon Lodge, across fr...
# 1              Geology Talk location at Sunset Point
# 2        Sunset Point, near the observation platform
# 3
# 4  Main hall in the Bryce Canyon Lodge, across fr...
# 5  Main hall in the Bryce Canyon Lodge, across fr...
# 6                        To be disclosed at sign-up.
# 7                   North Campground Outdoor Theater
# 8  Main hall in the Bryce Canyon Lodge, across fr...
# 9
#
#   contacttelephonenumber recurrencedateend    longitude   datestart  \
# 0                               2024-07-11  -112.167999  2024-07-03
# 1           435-834-5322        2024-12-31  -112.166955  2024-07-03
# 2                               2024-07-13  -112.165988  2024-07-03
# 3                               2024-07-27               2024-07-04
# 4                               2024-07-11  -112.167999  2024-07-04
# ...

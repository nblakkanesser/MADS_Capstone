# %%
#File to track needed intalls - should be adding versions to these things?
#or some other (docker etc.) environment saver
# ! python -m pip install --upgrade pip
# ! python --version

! pip install requests
! pip install numpy
! pip install pandas

#potential others to install:
! pip install matplotlib
! pip install statsmodels
! pip install seaborn
! pip install scikit-learn
! pip install scikit-learn-extra
! pip install geopandas
! pip install nbformat
! pip install "pydantic<2"
! pip install openai==1.9.0
! pip install nbconvert
! pip install flask
! pip install ragas #for LLM evaluation if needed
! pip install spacy
! pip install $(spacy info en_core_web_sm --url)
! pip install nltk
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# ...
